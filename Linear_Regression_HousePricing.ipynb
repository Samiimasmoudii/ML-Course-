# %% [markdown]
# <a href="https://colab.research.google.com/github/Samiimasmoudii/ML-Course-/blob/main/TP1_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
house_data = pd.read_csv('house.csv')

# %%
house_data
# Out:
#      loyer  surface
# 0     1330       37
# 1     1400       32
# 2      904       26
# 3      955       30
# 4     2545       70
# ..     ...      ...
# 540   1490       48
# 541   2020       58
# 542   2050       70
# 543   1220       42
# 544   1610       44
#
# [545 rows x 2 columns]

# %%
plt.plot(house_data['surface'],house_data['loyer'], 'ro')
plt.show()

# %%
house_data_raw = pd.read_csv('house.csv')
house_data = house_data_raw[house_data_raw['loyer']<7000]

# %%
plt.plot(house_data['surface'],house_data['loyer'],'ro')
plt.show()

# %%
plt.plot(house_data['surface'],house_data['loyer'],'ro',markersize=2)
plt.show()

# %%
surface=house_data['surface'].values
loyer=house_data['loyer'].values
x = np.column_stack((np.ones(len(surface)), surface))

# Convert `y` (loyer) to a NumPy array
y = np.array(loyer)

# Calculate theta using the normal equation
theta = np.linalg.inv(x.T.dot(x)).dot(x.T).dot(y)

# %%
import random
print('Theta 0 =',theta[0])
print('Theta 1 =',theta[1])
print("L'equation est Y^i = ",theta[0],"+",theta[1]," * Xi")
xtest=random.randint(50,200)
print("pour X = ",xtest, "y =",theta[0]+theta[1]*xtest )
xtest=random.randint(50,200)
print("pour X = ",xtest, "y =",theta[0]+theta[1]*xtest )
xtest=random.randint(50,200)
print("pour X = ",xtest, "y =",theta[0]+theta[1]*xtest )
# Out:
# Theta 0 = 359.5226617782226
# Theta 1 = 28.668778503202248
# L'equation est Y^i =  359.5226617782226 + 28.668778503202248  * Xi
# pour X =  154 y = 4774.514551271369
# pour X =  171 y = 5261.883785825807
# pour X =  159 y = 4917.85844378738

# %%
import matplotlib.pyplot as plt

# Tracer le nuage de points
plt.scatter(surface, loyer, color='blue', label='Données réelles')

# Tracer la droite de régression
x_vals = np.array([min(surface), max(surface)])  # Points pour la ligne droite (x1 et x2)
y_vals = theta[0] + theta[1] * x_vals  # Calcul des valeurs correspondantes de y (y1 et y2)
plt.plot(x_vals, y_vals, color='red', label='Régression linéaire',markersize=0.5)

# Ajouter des labels et une légende
plt.xlabel('Surface (m²)')
plt.ylabel('Loyer (TND)')
plt.title('Régression linéaire - Loyer vs Surface')
plt.legend()

# Afficher la figure
plt.show()
